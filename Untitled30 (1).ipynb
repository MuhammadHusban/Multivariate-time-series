# %%
# First we will import the necessary Library 

import os
import pandas as pd
import numpy as np
import math
import datetime as dt
import matplotlib.pyplot as plt

# For Evalution we will use these library

from sklearn.metrics import mean_squared_error, mean_absolute_error, explained_variance_score, r2_score 
from sklearn.metrics import mean_poisson_deviance, mean_gamma_deviance, accuracy_score
from sklearn.preprocessing import MinMaxScaler

# For model building we will use these library

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM


# For PLotting we will use these library

import matplotlib.pyplot as plt
from itertools import cycle
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots

# %%
maindf = pd.read_csv("/content/oil_raw.csv")

# %%
maindf.head()
# Out:
#          date   Open   High    Low  Close     Vol  Change %
# 0  10/14/2022  92.81  93.45  89.81  90.15  153.89   -0.0467
# 1  10/13/2022  92.49  94.92  91.08  94.57  280.52    0.0229
# 2  10/12/2022  93.72  95.17  91.56  92.45  257.66   -0.0195
# 3  10/11/2022  95.93  96.46  93.11  94.29  259.03   -0.0198
# 4  10/10/2022  98.75  98.75  95.60  96.19  215.37   -0.0177

# %%
maindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      3280 non-null   object
#  1   Open      3280 non-null   float64
#  2   High      3280 non-null   float64
#  3   Low       3280 non-null   float64
#  4   Close     3280 non-null   float64
#  5   Vol       3277 non-null   float64
#  6   Change %  3280 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 179.5+ KB

# %%
maindf.isnull().sum()
# Out:
# date        0
# Open        0
# High        0
# Low         0
# Close       0
# Vol         3
# Change %    0
# dtype: int64

# %%
print('Total number of days present in the dataset: ',maindf.shape[0])
print('Total number of fields present in the dataset: ',maindf.shape[1])
# Out:
# Total number of days present in the dataset:  3280
# Total number of fields present in the dataset:  7

# %%
maindf.shape
# Out:
# (3280, 7)

# %%
maindf.describe()
# Out:
#               Open         High          Low        Close          Vol  \
# count  3280.000000  3280.000000  3280.000000  3280.000000  3277.000000
# mean     77.794741    78.819476    76.723098    77.813015   220.073195
# std      26.021711    26.181170    25.853465    26.059086    93.840000
# min      19.900000    21.290000    15.980000    19.330000     5.890000
# 25%      55.925000    56.620000    55.200000    55.910000   164.960000
# 50%      73.735000    74.670000    72.565000    73.595000   217.750000
# 75%     106.170000   107.450000   105.005000   106.287500   277.280000
# max     130.280000   139.130000   125.000000   127.980000   779.720000
#
#           Change %
# count  3280.000000
# mean      0.000330
# std       0.022827
# min      -0.244000
# 25%      -0.009500
# 50%       0.000950
# 75%       0.010725
# max       0.210200

# %%
print('Null Values:',maindf.isnull().values.sum())
# Out:
# Null Values: 3

# %%
print('NA values:',maindf.isnull().values.any())
# Out:
# NA values: True

# %%
Date = maindf["date"]

# %%
Date = pd.to_datetime(Date)

# %%
Date
# Out:
# 0      2022-10-14
# 1      2022-10-13
# 2      2022-10-12
# 3      2022-10-11
# 4      2022-10-10
#           ...
# 3275   2010-02-11
# 3276   2010-02-10
# 3277   2010-02-09
# 3278   2010-02-08
# 3279   2010-02-05
# Name: date, Length: 3280, dtype: datetime64[ns]

# %%
maindf.drop("date",inplace= True,axis=1)

# %%
Date = pd.DataFrame(Date)
maindf = pd.concat([Date,maindf],axis = 1)

# %%
maindf.head()
# Out:
#         date   Open   High    Low  Close     Vol  Change %
# 0 2022-10-14  92.81  93.45  89.81  90.15  153.89   -0.0467
# 1 2022-10-13  92.49  94.92  91.08  94.57  280.52    0.0229
# 2 2022-10-12  93.72  95.17  91.56  92.45  257.66   -0.0195
# 3 2022-10-11  95.93  96.46  93.11  94.29  259.03   -0.0198
# 4 2022-10-10  98.75  98.75  95.60  96.19  215.37   -0.0177

# %%
# Printing the start date and End date of the dataset

ed=maindf.iloc[0][0]
sd=maindf.iloc[-1][0]


print('Starting Date',sd)
print('Ending Date',ed)
# Out:
# Starting Date 2010-02-05 00:00:00
# Ending Date 2022-10-14 00:00:00

# %%
maindf['date'] = pd.to_datetime(maindf['date'], format='%Y-%m-%d')
y_2010 = maindf.loc[(maindf['date'] >= '2010-02-05')
                     & (maindf['date'] < '2010-12-31')]

y_2010.drop(y_2010[['Change %','Vol']],axis=1)
# Out:
#            date   Open   High    Low  Close
# 3046 2010-12-30  94.18  94.42  92.34  93.09
# 3047 2010-12-29  94.34  94.38  93.62  94.14
# 3048 2010-12-28  93.90  94.42  93.66  94.38
# 3049 2010-12-27  93.76  94.52  93.08  93.85
# 3050 2010-12-24  94.45  94.74  93.18  93.77
# ...         ...    ...    ...    ...    ...
# 3275 2010-02-11  72.80  73.58  72.02  73.05
# 3276 2010-02-10  71.89  73.00  70.83  72.54
# 3277 2010-02-09  69.63  72.47  69.61  72.13
# 3278 2010-02-08  70.36  70.82  69.21  70.11
# 3279 2010-02-05  72.13  72.52  67.87  69.59
#
# [234 rows x 5 columns]

# %%
monthvise= y_2010.groupby(y_2010['date'].dt.strftime('%B'))[['Open','Close']].mean()
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
             'September', 'October', 'November', 'December']
monthvise = monthvise.reindex(new_order, axis=0)
monthvise
# Out:
#                 Open      Close
# date
# January          NaN        NaN
# February   74.589375  74.911250
# March      79.759565  79.931304
# April      85.552381  85.753810
# May        77.606190  76.997619
# June       75.618182  75.658636
# July       75.186364  75.356364
# August     77.247273  77.115000
# September  78.039091  78.417273
# October    83.486667  83.536190
# November   86.062273  86.159545
# December   91.794091  92.141364

# %%
fig = go.Figure()

fig.add_trace(go.Bar(
    x=monthvise.index,
    y=monthvise['Open'],
    name='Stock Open Price',
    marker_color='crimson'
))
fig.add_trace(go.Bar(
    x=monthvise.index,
    y=monthvise['Close'],
    name='Stock Close Price',
    marker_color='lightsalmon'
))

fig.update_layout(barmode='group', xaxis_tickangle=-45, 
                  title='Monthwise comparision between Stock open and close price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
y_2010.groupby(y_2010['date'].dt.strftime('%B'))['Low'].min()
monthvise_high = y_2010.groupby(maindf['date'].dt.strftime('%B'))['High'].max()
monthvise_high = monthvise_high.reindex(new_order, axis=0)

monthvise_low = y_2010.groupby(y_2010['date'].dt.strftime('%B'))['Low'].min()
monthvise_low = monthvise_low.reindex(new_order, axis=0)

fig = go.Figure()
fig.add_trace(go.Bar(
    x=monthvise_high.index,
    y=monthvise_high,
    name='Stock high Price',
    marker_color='rgb(0, 153, 204)'
))
fig.add_trace(go.Bar(
    x=monthvise_low.index,
    y=monthvise_low,
    name='Stock low Price',
    marker_color='rgb(255, 128, 0)'
))

fig.update_layout(barmode='group', 
                  title=' Monthwise High and Low stock price')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
names = cycle(['Stock Open Price','Stock Close Price','Stock High Price','Stock Low Price'])

fig = px.line(y_2010, x=y_2010.date, y=[y_2010['Open'], y_2010['Close'], 
                                          y_2010['High'], y_2010['Low']],
             labels={'Date': 'Date','value':'Stock value'})
fig.update_layout(title_text='Stock analysis chart', font_size=15, font_color='black',legend_title_text='Stock Parameters')
fig.for_each_trace(lambda t:  t.update(name = next(names)))
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
maindf['Date'] = pd.to_datetime(maindf['date'], format='%Y-%m-%d')

y_overall = maindf.loc[(maindf['date'] >= '2010-02-05')
                     & (maindf['date'] <= ' 2022-10-14')]

y_overall.drop(y_overall[['Change %','Vol']],axis=1)
# Out:
#            date   Open   High    Low  Close       Date
# 0    2022-10-14  92.81  93.45  89.81  90.15 2022-10-14
# 1    2022-10-13  92.49  94.92  91.08  94.57 2022-10-13
# 2    2022-10-12  93.72  95.17  91.56  92.45 2022-10-12
# 3    2022-10-11  95.93  96.46  93.11  94.29 2022-10-11
# 4    2022-10-10  98.75  98.75  95.60  96.19 2022-10-10
# ...         ...    ...    ...    ...    ...        ...
# 3275 2010-02-11  72.80  73.58  72.02  73.05 2010-02-11
# 3276 2010-02-10  71.89  73.00  70.83  72.54 2010-02-10
# 3277 2010-02-09  69.63  72.47  69.61  72.13 2010-02-09
# 3278 2010-02-08  70.36  70.82  69.21  70.11 2010-02-08
# 3279 2010-02-05  72.13  72.52  67.87  69.59 2010-02-05
#
# [3280 rows x 6 columns]

# %%
monthvise= y_overall.groupby(y_overall['date'].dt.strftime('%B'))[['Open','Close']].mean()
new_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 
             'September', 'October', 'November', 'December']
monthvise = monthvise.reindex(new_order, axis=0)
monthvise
# Out:
#                 Open      Close
# date
# January    75.313035  75.361868
# February   77.830039  77.976667
# March      79.311224  79.211014
# April      79.799814  79.906543
# May        80.288084  80.230139
# June       79.167348  79.220968
# July       78.750418  78.765401
# August     77.615813  77.684014
# September  77.557419  77.510681
# October    77.835200  77.854945
# November   75.435930  75.379419
# December   73.881289  73.917852

# %%
names = cycle(['Stock Open Price','Stock Close Price','Stock High Price','Stock Low Price'])

fig = px.line(y_overall, x=y_overall.date, y=[y_overall['Open'], y_overall['Close'], 
                                          y_overall['High'], y_overall['Low']],
             labels={'Date': 'Date','value':'Stock value'})
fig.update_layout(title_text='Stock analysis chart', font_size=15, font_color='black',legend_title_text='Stock Parameters')
fig.for_each_trace(lambda t:  t.update(name = next(names)))
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Lets First Take all the Close Price 
closedf = maindf[['date','Close']]
print("Shape of close dataframe:", closedf.shape)
# Out:
# Shape of close dataframe: (3280, 2)

# %%
fig = px.line(closedf, x=closedf.date, y=closedf.Close,labels={'date':'date','close':'Close Stock'})
fig.update_traces(marker_line_width=2, opacity=0.8, marker_line_color='orange')
fig.update_layout(title_text='Whole period of timeframe of close price 2014-2022', plot_bgcolor='white', 
                  font_size=15, font_color='black')
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
closedf = closedf[closedf['date'] > '2021-10-14']
close_stock = closedf.copy()
print("Total data for prediction: ",closedf.shape[0])
# Out:
# Total data for prediction:  260

# %%
closedf
# Out:
#           date  Close
# 0   2022-10-14  90.15
# 1   2022-10-13  94.57
# 2   2022-10-12  92.45
# 3   2022-10-11  94.29
# 4   2022-10-10  96.19
# ..         ...    ...
# 255 2021-10-21  84.61
# 256 2021-10-20  85.82
# 257 2021-10-19  85.08
# 258 2021-10-18  84.33
# 259 2021-10-15  84.86
#
# [260 rows x 2 columns]

# %%
fig = px.line(closedf, x=closedf.date, y=closedf.Close,labels={'date':'date','close':'Close Stock'})
fig.update_traces(marker_line_width=2, opacity=0.8, marker_line_color='orange')
fig.update_layout(title_text='Considered period to predict close price', 
                  plot_bgcolor='white', font_size=15, font_color='black')
fig.update_xaxes(showgrid=False)
fig.update_yaxes(showgrid=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data = pd.read_excel("/content/data.xlsx")

# %%
data.head()
# Out:
#         date  return (t-1)  Positive (t-1)  Negative (t-1)  Neutral (t-1)  \
# 0 2010-02-17        0.0437        0.063710        0.111507       0.824784
# 1 2010-02-19        0.0078        0.070926        0.087685       0.841389
# 2 2010-02-22        0.0053        0.047434        0.219664       0.732902
# 3 2010-02-23        0.0054        0.180921        0.091316       0.727764
# 4 2010-02-24       -0.0173        0.223923        0.056738       0.719339
#
#    gold (t-1)  inflation (t-1)  djia (t-1)  goldman (t-1)  dollars (t-1)  \
# 0     0.01707           0.0224    0.016661       0.031985      -0.008490
# 1    -0.00425           0.0228    0.003929       0.000229       0.008987
# 2    -0.00450           0.0226    0.000909       0.006579       0.003164
# 3    -0.00461           0.0225   -0.001825       0.000803      -0.001674
# 4    -0.01052           0.0219   -0.009772      -0.017655       0.004025
#
#    Positive_7_cumulative_score (t-1)  Negative_7_cumulative_score (t-1)  \
# ...

# %%
data.drop(["date","oil (t)"],axis=1,inplace=True)

# %%
data.head()
# Out:
#    return (t-1)  Positive (t-1)  Negative (t-1)  Neutral (t-1)  gold (t-1)  \
# 0        0.0437        0.063710        0.111507       0.824784     0.01707
# 1        0.0078        0.070926        0.087685       0.841389    -0.00425
# 2        0.0053        0.047434        0.219664       0.732902    -0.00450
# 3        0.0054        0.180921        0.091316       0.727764    -0.00461
# 4       -0.0173        0.223923        0.056738       0.719339    -0.01052
#
#    inflation (t-1)  djia (t-1)  goldman (t-1)  dollars (t-1)  \
# 0           0.0224    0.016661       0.031985      -0.008490
# 1           0.0228    0.003929       0.000229       0.008987
# 2           0.0226    0.000909       0.006579       0.003164
# 3           0.0225   -0.001825       0.000803      -0.001674
# 4           0.0219   -0.009772      -0.017655       0.004025
#
#    Positive_7_cumulative_score (t-1)  Negative_7_cumulative_score (t-1)  \
# ...

# %%
data.shape
# Out:
# (3132, 15)

# %%
maindf.head()
# Out:
#         date   Open   High    Low  Close     Vol  Change %       Date
# 0 2022-10-14  92.81  93.45  89.81  90.15  153.89   -0.0467 2022-10-14
# 1 2022-10-13  92.49  94.92  91.08  94.57  280.52    0.0229 2022-10-13
# 2 2022-10-12  93.72  95.17  91.56  92.45  257.66   -0.0195 2022-10-12
# 3 2022-10-11  95.93  96.46  93.11  94.29  259.03   -0.0198 2022-10-11
# 4 2022-10-10  98.75  98.75  95.60  96.19  215.37   -0.0177 2022-10-10

# %%
maindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      3280 non-null   datetime64[ns]
#  1   Open      3280 non-null   float64
#  2   High      3280 non-null   float64
#  3   Low       3280 non-null   float64
#  4   Close     3280 non-null   float64
#  5   Vol       3277 non-null   float64
#  6   Change %  3280 non-null   float64
#  7   Date      3280 non-null   datetime64[ns]
# dtypes: datetime64[ns](2), float64(6)
# memory usage: 205.1 KB

# %%
maindf.drop(["Open","High","Low","Vol","Change %","Date"],axis = 1 ,inplace=True)

# %%
finaldf = pd.concat([maindf,data],axis = 1)
finaldf.head()
# Out:
#         date  Close  return (t-1)  Positive (t-1)  Negative (t-1)  \
# 0 2022-10-14  90.15        0.0437        0.063710        0.111507
# 1 2022-10-13  94.57        0.0078        0.070926        0.087685
# 2 2022-10-12  92.45        0.0053        0.047434        0.219664
# 3 2022-10-11  94.29        0.0054        0.180921        0.091316
# 4 2022-10-10  96.19       -0.0173        0.223923        0.056738
#
#    Neutral (t-1)  gold (t-1)  inflation (t-1)  djia (t-1)  goldman (t-1)  \
# 0       0.824784     0.01707           0.0224    0.016661       0.031985
# 1       0.841389    -0.00425           0.0228    0.003929       0.000229
# 2       0.732902    -0.00450           0.0226    0.000909       0.006579
# 3       0.727764    -0.00461           0.0225   -0.001825       0.000803
# 4       0.719339    -0.01052           0.0219   -0.009772      -0.017655
#
#    dollars (t-1)  Positive_7_cumulative_score (t-1)  \
# 0      -0.008490                           0.803115
# ...

# %%
finaldf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3280 entries, 0 to 3279
# Data columns (total 17 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   date                               3280 non-null   datetime64[ns]
#  1   Close                              3280 non-null   float64
#  2   return (t-1)                       3132 non-null   float64
#  3   Positive (t-1)                     3132 non-null   float64
#  4   Negative (t-1)                     3132 non-null   float64
#  5   Neutral (t-1)                      3132 non-null   float64
#  6   gold (t-1)                         3132 non-null   float64
#  7   inflation (t-1)                    3132 non-null   float64
#  8   djia (t-1)                         3132 non-null   float64
#  9   goldman (t-1)                      3132 non-null   float64
#  10  dollars (t-1)                      3132 non-null   float64
# ...

# %%
df = finaldf

# %%
df = df.dropna()

# %%
from sklearn.preprocessing import StandardScaler
Scale=StandardScaler()
def data_prep(df, lookback, future, Scale):
    date_train=pd.to_datetime(df['date'])
    df_train=df[["Close",	"return (t-1)",	"Positive (t-1)",	"Negative (t-1)"	,"Neutral (t-1)"	,"gold (t-1)","inflation (t-1)"	,"djia (t-1)"	,"goldman (t-1)"	,"dollars (t-1)"	,"Positive_7_cumulative_score (t-1)"	,'Negative_7_cumulative_score (t-1)'	,'Neutral_7_cumulative_score (t-1)'	,'oil_2_day_volatility (t-1)'	,'oil_3_day_volatility (t-1)'	,'oil_5_day_volatility (t-1)']]
    df_train=df_train.astype(float)
    
    df_train_scaled=Scale.fit_transform(df_train)

    X, y =[],[]
    for i in range(lookback, len(df_train_scaled)-future+1):
        X.append(df_train_scaled[i-lookback:i, 0:df_train.shape[1]])
        y.append(df_train_scaled[i+future-1:i+future, 0])
        
    return np.array(X), np.array(y), df_train, date_train

Lstm_x, Lstm_y, df_train, date_train = data_prep(df, 30, 1, Scale)

# %%
def predict_open(model,date_train,Lstm_x,df_train, future, Scale):
    forecasting_dates=pd.date_range(list(date_train)[-1], periods=future, freq='1d').tolist()
    predicted=model.predict(Lstm_x[-future:])
    predicted1=np.repeat(predicted, df_train.shape[1], axis=-1)
    predicted_descaled=Scale.inverse_transform(predicted1)[:,0]
    return predicted_descaled,forecasting_dates

def output_prep(forecasting_dates,predicted_descaled):
    dates=[]
    for i in forecasting_dates:
        dates.append(i.date())
    df_final=pd.DataFrame(columns=['date','Close'])
    df_final['date']=pd.to_datetime(dates)
    df_final['Close']=predicted_descaled
    return df_final

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(Lstm_x,Lstm_y,test_size = 0.2,random_state = 0)

# %%
Lstm_x.shape[1]
# Out:
# 30

# %%
x_train.shape
# Out:
# (2481, 30, 16)

# %%
from keras.layers import Bidirectional
model = Sequential()
model.add(Bidirectional(LSTM(units=250, return_sequences=True, input_shape = (x_train.shape[1],x_train.shape[2])) ))
model.add(Dropout(0.2))
model.add(LSTM(units= 30 , return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units= 30))
model.add(Dropout(0.2))
# model.add(LSTM(units= 30))
# model.add(Dropout(0.2))
model.add(Dense(1,activation = "linear"))
model.compile(loss="mean_squared_error",optimizer="adam")

# %%
history = model.fit(x_train,y_train,validation_split=0.2,epochs=50,batch_size=32,verbose=1)
# Out:
# Epoch 1/50
# 62/62 [==============================] - 26s 293ms/step - loss: 0.1281 - val_loss: 0.0171
# Epoch 2/50
# 62/62 [==============================] - 14s 226ms/step - loss: 0.0391 - val_loss: 0.0182
# Epoch 3/50
# 62/62 [==============================] - 15s 238ms/step - loss: 0.0362 - val_loss: 0.0148
# Epoch 4/50
# 62/62 [==============================] - 14s 230ms/step - loss: 0.0301 - val_loss: 0.0177
# Epoch 5/50
# 62/62 [==============================] - 14s 229ms/step - loss: 0.0282 - val_loss: 0.0139
# Epoch 6/50
# 62/62 [==============================] - 15s 240ms/step - loss: 0.0285 - val_loss: 0.0148
# Epoch 7/50
# 62/62 [==============================] - 14s 227ms/step - loss: 0.0244 - val_loss: 0.0109
# Epoch 8/50
# 62/62 [==============================] - 16s 257ms/step - loss: 0.0242 - val_loss: 0.0173
# Epoch 9/50
# 62/62 [==============================] - 15s 240ms/step - loss: 0.0238 - val_loss: 0.0091
# Epoch 10/50
# ...

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(loss))

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.figure()


plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 20/20 [==============================] - 3s 67ms/step

# %%
y_pred
# Out:
# array([[ 2.35214606e-01],
#        [-2.74787813e-01],
#        [ 1.33593524e+00],
#        [ 1.20131123e+00],
#        [-2.83436537e-01],
#        [ 1.92360640e-01],
#        [-4.47546244e-01],
#        [ 1.10467482e+00],
#        [ 1.26812303e+00],
#        [-5.13095915e-01],
#        [-1.18703961e+00],
#        [-1.31746769e+00],
#        [-2.49439985e-01],
#        [-9.61591542e-01],
#        [-9.57787454e-01],
#        [-1.51936603e+00],
#        [ 1.19364083e+00],
#        [-1.30864370e+00],
#        [ 7.09020138e-01],
#        [-1.41339466e-01],
#        [-1.18294632e+00],
#        [-2.46870041e-01],
#        [ 1.18437052e+00],
#        [ 1.07787097e+00],
#        [-4.50232923e-01],
#        [ 1.21515727e+00],
#        [ 1.24874544e+00],
#        [ 1.24788237e+00],
#        [-6.71870932e-02],
#        [-5.31181633e-01],
#        [ 1.21230149e+00],
#        [ 1.07608426e+00],
#        [-5.25662303e-01],
#        [-5.07485271e-01],
#        [ 8.18522871e-02],
# ...

# %%
y_pred.shape
# Out:
# (621, 1)

# %%
#Checking how much well our model predicting 
fig, ax = plt.subplots(figsize = (50,20))

plt.title("Y_pred vs Y_test")
#The blue line is for y_pred wich is our model predicted data
ax.plot(y_pred,label = 'y_pred')
#THE red line is for y_test which is our original data
ax.plot(y_test,label = "y_test", c='r')
plt.legend()

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(x_train)
test_predict=model.predict(x_test)
train_predict.shape, test_predict.shape
# Out:
# ...
# 20/20 [==============================] - 2s 107ms/step
# ((2481, 1), (621, 1))

# %%
#Checking how much well our model predicting 
fig, ax = plt.subplots(figsize = (50,20))

plt.title("Y_pred vs Y_test")
#The blue line is for y_pred wich is our model predicted data
ax.plot(y_pred,label = 'y_pred')
#THE red line is for y_test which is our original data
# ax.plot(y_test,label = "y_test", c='r')
plt.legend()
